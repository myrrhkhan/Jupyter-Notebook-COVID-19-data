# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file = "Google_Mobility_Report.csv"

df = pd.read_csv("Google_Mobility_Report.csv", low_memory=False) #low_memory=False is to adjust dtype, whatever that is.
#Much easier than Johns Hopkins in that there is one file, so all we need to do is read that csv file into a table.

df.fillna(0)
df
# Out:
#        country_region_code        country_region sub_region_1 sub_region_2  \
# 0                       AE  United Arab Emirates          NaN          NaN
# 1                       AE  United Arab Emirates          NaN          NaN
# 2                       AE  United Arab Emirates          NaN          NaN
# 3                       AE  United Arab Emirates          NaN          NaN
# 4                       AE  United Arab Emirates          NaN          NaN
# ...                    ...                   ...          ...          ...
# 335458                  ZW              Zimbabwe          NaN          NaN
# 335459                  ZW              Zimbabwe          NaN          NaN
# 335460                  ZW              Zimbabwe          NaN          NaN
# 335461                  ZW              Zimbabwe          NaN          NaN
# 335462                  ZW              Zimbabwe          NaN          NaN
#
#               date  retail_and_recreation_percent_change_from_baseline  \
# 0       2020-02-15                                                0.0
# 1       2020-02-16                                                1.0
# 2       2020-02-17                                               -1.0
# 3       2020-02-18                                               -2.0
# 4       2020-02-19                                               -2.0
# ...            ...                                                ...
# 335458  2020-05-05                                              -40.0
# 335459  2020-05-06                                              -37.0
# 335460  2020-05-07                                              -35.0
# 335461  2020-05-08                                              -38.0
# 335462  2020-05-09                                              -38.0
#
#         grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                     4.0
# 1                                                     4.0
# 2                                                     1.0
# 3                                                     1.0
# 4                                                     0.0
# ...                                                   ...
# 335458                                              -31.0
# 335459                                              -26.0
# 335460                                              -25.0
# 335461                                              -25.0
# 335462                                              -22.0
#
#         parks_percent_change_from_baseline  \
# 0                                      5.0
# 1                                      4.0
# 2                                      5.0
# 3                                      5.0
# 4                                      4.0
# ...                                    ...
# 335458                               -30.0
# 335459                               -31.0
# 335460                               -34.0
# 335461                               -35.0
# 335462                               -30.0
#
#         transit_stations_percent_change_from_baseline  \
# 0                                                 0.0
# 1                                                 1.0
# 2                                                 1.0
# 3                                                 0.0
# 4                                                -1.0
# ...                                               ...
# 335458                                          -61.0
# 335459                                          -57.0
# 335460                                          -57.0
# 335461                                          -59.0
# 335462                                          -57.0
#
#         workplaces_percent_change_from_baseline  \
# 0                                           2.0
# 1                                           2.0
# 2                                           2.0
# 3                                           2.0
# 4                                           2.0
# ...                                         ...
# 335458                                    -39.0
# 335459                                    -38.0
# 335460                                    -37.0
# 335461                                    -33.0
# 335462                                    -24.0
#
#         residential_percent_change_from_baseline
# 0                                            1.0
# 1                                            1.0
# 2                                            1.0
# 3                                            1.0
# 4                                            1.0
# ...                                          ...
# 335458                                      30.0
# 335459                                      31.0
# 335460                                      31.0
# 335461                                      31.0
# 335462                                      24.0
#
# [335463 rows x 11 columns]

# %%
usa = df['country_region'] == 'United States'
df[usa] = df[df['country_region'] == 'United States']
#Makes new data frame in which all of the data table values have united states as country_region. Source: https://towardsdatascience.com/apply-and-lambda-usage-in-pandas-b13a1ea037f7
#df[usa] is a new dataframe.
#df['country_region]=='United States' takes all of the data with US in it, and putting "df[]" around it makes a data table of it.
df[usa]
# Out:
#        country_region_code country_region sub_region_1   sub_region_2  \
# 103361                  US  United States          NaN            NaN
# 103362                  US  United States          NaN            NaN
# 103363                  US  United States          NaN            NaN
# 103364                  US  United States          NaN            NaN
# 103365                  US  United States          NaN            NaN
# ...                    ...            ...          ...            ...
# 332483                  US  United States      Wyoming  Weston County
# 332484                  US  United States      Wyoming  Weston County
# 332485                  US  United States      Wyoming  Weston County
# 332486                  US  United States      Wyoming  Weston County
# 332487                  US  United States      Wyoming  Weston County
#
#               date  retail_and_recreation_percent_change_from_baseline  \
# 103361  2020-02-15                                                6.0
# 103362  2020-02-16                                                7.0
# 103363  2020-02-17                                                6.0
# 103364  2020-02-18                                                0.0
# 103365  2020-02-19                                                2.0
# ...            ...                                                ...
# 332483  2020-05-04                                                NaN
# 332484  2020-05-05                                                NaN
# 332485  2020-05-06                                                NaN
# 332486  2020-05-07                                                NaN
# 332487  2020-05-08                                                NaN
#
#         grocery_and_pharmacy_percent_change_from_baseline  \
# 103361                                                2.0
# 103362                                                1.0
# 103363                                                0.0
# 103364                                               -1.0
# 103365                                                0.0
# ...                                                   ...
# 332483                                                NaN
# 332484                                                NaN
# 332485                                                NaN
# 332486                                                NaN
# 332487                                                NaN
#
#         parks_percent_change_from_baseline  \
# 103361                                15.0
# 103362                                16.0
# 103363                                28.0
# 103364                                 6.0
# 103365                                 8.0
# ...                                    ...
# 332483                                 NaN
# 332484                                 NaN
# 332485                                 NaN
# 332486                                 NaN
# 332487                                 NaN
#
#         transit_stations_percent_change_from_baseline  \
# 103361                                            3.0
# 103362                                            2.0
# 103363                                           -9.0
# 103364                                            1.0
# 103365                                            1.0
# ...                                               ...
# 332483                                            NaN
# 332484                                            NaN
# 332485                                            NaN
# 332486                                            NaN
# 332487                                            NaN
#
#         workplaces_percent_change_from_baseline  \
# 103361                                      2.0
# 103362                                      0.0
# 103363                                    -24.0
# 103364                                      0.0
# 103365                                      1.0
# ...                                         ...
# 332483                                    -34.0
# 332484                                    -34.0
# 332485                                    -35.0
# 332486                                    -32.0
# 332487                                    -35.0
#
#         residential_percent_change_from_baseline
# 103361                                      -1.0
# 103362                                      -1.0
# 103363                                       5.0
# 103364                                       1.0
# 103365                                       0.0
# ...                                          ...
# 332483                                       NaN
# 332484                                       NaN
# 332485                                       NaN
# 332486                                       NaN
# 332487                                       NaN
#
# [229127 rows x 11 columns]

# %%
countries = ['United States']
states = ['Virginia']
counties = ['Fairfax County']

for county in counties:
    s = df[df['sub_region_2'] == county]
    plt.plot(s['date'], s['retail_and_recreation_percent_change_from_baseline'], label = county)
  
plt.legend()
plt.show()

# %%
countries = ['United States']
states = ['Virginia']
counties = ['Fairfax County', 'Fairfax', 'Loudoun County', 'Stafford County']

for county in counties:
    s = df[df['sub_region_2'] == county]
    plt.plot(s['date'], s['retail_and_recreation_percent_change_from_baseline'], label = county)

plt.legend()
plt.show()

# %% [raw]
# Google Mobility Data
